# %%
[*(1,2,3)]
# Out:
# [1, 2, 3]

# %%
1,2,3
# Out:
# (1, 2, 3)

# %%
1,
# Out:
# (1,)

# %%
def f(*args):
    print(type(args))

# %%
f(1,2,3)
# Out:
# <class 'tuple'>

# %%
print(type((1,2,3)))
# Out:
# <class 'tuple'>

# %%
print(*(1,2,3))
# Out:
# 1 2 3

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
def f(a, *args):
    print(a, args)

# %%
f(1,2)
# Out:
# 1 (2,)

# %%
t = 3
tt = 'testing'

# %%
d = {t:3, tt:2}

# %%
d
# Out:
# {3: 3, 'testing': 2}

# %%
def f(**kwargs):
    print(type(kwargs))
    print(kwargs)

# %%
f(a=1,b=2,c=0,d23_44j=3)
# Out:
# <class 'dict'>
# {'a': 1, 'b': 2, 'c': 0, 'd23_44j': 3}

# %% [markdown]
# #

# %%
plt.isinteractive()
# Out:
# True

# %%
plt.ioff()

# %%
plt.isinteractive()
# Out:
# False

# %%
plt.plot([1,2],[1,2])

# %%
plt.show()

# %%
plt.ion()

# %%
plt.isinteractive()
# Out:
# True

# %%
plt.plot([1,2],[1,2])

# %% [markdown]
# #

# %%
def f(*args):

    '''
    testing
    
    testing
    '''
    
    for i in args:
        print(i)

# %%
help(f)
# Out:
# Help on function f in module __main__:
#
# f(*args)
#     testing
#
#     testing

# %%
f(*[[1],[2]])
# Out:
# [1]
# [2]

# %% [markdown]
# #

# %%
x = np.random.uniform(size=(2,10))
x
# Out:
# array([[0.63766819, 0.63923156, 0.55546057, 0.69594811, 0.08222335,
#         0.06642099, 0.77925757, 0.21722516, 0.51291846, 0.89831892],
#        [0.14409104, 0.43100456, 0.05784599, 0.74344136, 0.13299543,
#         0.54834129, 0.16858201, 0.64291622, 0.79363158, 0.99921997]])

# %%
plt.scatter(*x)

# %%
plt.plot(*x)

# %%
from IPython.display import Markdown

# %%
fig, ax = plt.subplots()
ax.scatter(*x)
display(Markdown('### testing $\hat\sigma$'))
display(fig)
display(Markdown('### testing $\hat\sigma$'))
display(ax.plot(*x))
# Out:
# ### testing $\hat\sigma$
# ### testing $\hat\sigma$

# %%
Markdown('### testing $\hat\sigma$')
# Out:
# ### testing $\hat\sigma$

# %%
collections = ax.collections[0]

# %%
collections

# %%
del ax.collections[0]

# %%
fig

# %%
ax.collections.append(collections)

# %%
fig

# %%
del ax.lines[0]

# %%
fig

# %% [markdown]
# #

# %%
fig

# %%
ax.set_title(r'$\sigma$')
# Out:
# Text(0.5, 1.0, '$\\sigma$')

# %%
fig

# %%
ax.legend(['testing'])

# %%
fig

# %% [markdown]
# #

# %%
sorted([(3,5,1),(3,4)])
# Out:
# [(3, 4), (3, 5, 1)]

# %%
sorted(['testing', 'test', 'a', 'c', 'zaa'])
# Out:
# ['a', 'c', 'test', 'testing', 'zaa']

# %%
x
# Out:
# array([[0.63766819, 0.63923156, 0.55546057, 0.69594811, 0.08222335,
#         0.06642099, 0.77925757, 0.21722516, 0.51291846, 0.89831892],
#        [0.14409104, 0.43100456, 0.05784599, 0.74344136, 0.13299543,
#         0.54834129, 0.16858201, 0.64291622, 0.79363158, 0.99921997]])

# %%
sorted(zip(*x))
# Out:
# [(0.06642098956908671, 0.5483412857116031),
#  (0.08222334823379207, 0.13299542633308958),
#  (0.2172251609889344, 0.64291621519647),
#  (0.5129184559806386, 0.793631581383384),
#  (0.5554605721476632, 0.057845991036380884),
#  (0.6376681864002673, 0.14409103631025655),
#  (0.639231557432243, 0.4310045572883612),
#  (0.6959481070976667, 0.7434413581688492),
#  (0.7792575668958145, 0.16858200777937205),
#  (0.8983189234307547, 0.9992199675610901)]

# %%
np.array(sorted(zip(*x)))
# Out:
# array([[0.06642099, 0.54834129],
#        [0.08222335, 0.13299543],
#        [0.21722516, 0.64291622],
#        [0.51291846, 0.79363158],
#        [0.55546057, 0.05784599],
#        [0.63766819, 0.14409104],
#        [0.63923156, 0.43100456],
#        [0.69594811, 0.74344136],
#        [0.77925757, 0.16858201],
#        [0.89831892, 0.99921997]])

# %%
plt.plot(*np.array(sorted(zip(*x))).T)

# %%
x
# Out:
# array([[0.63766819, 0.63923156, 0.55546057, 0.69594811, 0.08222335,
#         0.06642099, 0.77925757, 0.21722516, 0.51291846, 0.89831892],
#        [0.14409104, 0.43100456, 0.05784599, 0.74344136, 0.13299543,
#         0.54834129, 0.16858201, 0.64291622, 0.79363158, 0.99921997]])

# %%
sorted([list(x[:,i]) for i in range(x.shape[1])] )
# Out:
# [[0.06642098956908671, 0.5483412857116031],
#  [0.08222334823379207, 0.13299542633308958],
#  [0.2172251609889344, 0.64291621519647],
#  [0.5129184559806386, 0.793631581383384],
#  [0.5554605721476632, 0.057845991036380884],
#  [0.6376681864002673, 0.14409103631025655],
#  [0.639231557432243, 0.4310045572883612],
#  [0.6959481070976667, 0.7434413581688492],
#  [0.7792575668958145, 0.16858200777937205],
#  [0.8983189234307547, 0.9992199675610901]]

# %% [markdown]
# #

# %% [markdown]
# # #

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
fig = plt.figure(figsize=[9.6, 7.2])
ax1 = plt.subplot(2,2,1)
ax2 = plt.subplot(2,2,3)
ax3 = plt.subplot(1,2,2)
plt.tight_layout(pad=2)

# %%
fig = plt.figure(figsize=[7.2, 7.2])
ax1 = plt.subplot2grid((3,3), (0,0), colspan=2, fig = fig)
ax2 = plt.subplot2grid((3,3), (1,0), rowspan=2, fig = fig)
ax3 = plt.subplot2grid((3,3), (1,1), colspan=2, fig = fig)
ax4 = plt.subplot2grid((3,3), (0,2), fig = fig)
plt.tight_layout()

# %% [markdown]
# #

# %%
import pandas_datareader as pdr

# %%
data = pdr.DataReader('AAPL', 'yahoo')['Adj Close']

# %%
data
# Out:
# Date
# 2016-01-15     22.497040
# 2016-01-19     22.388184
# 2016-01-20     22.418295
# 2016-01-21     22.304800
# 2016-01-22     23.490686
#                  ...
# 2021-01-07    130.919998
# 2021-01-08    132.050003
# 2021-01-11    128.979996
# 2021-01-12    128.800003
# 2021-01-13    131.399307
# Name: Adj Close, Length: 1258, dtype: float64

# %%
plt.plot(data)

# %%
data.index.astype(str)
# Out:
# Index(['2016-01-15', '2016-01-19', '2016-01-20', '2016-01-21', '2016-01-22',
#        '2016-01-25', '2016-01-26', '2016-01-27', '2016-01-28', '2016-01-29',
#        ...
#        '2020-12-30', '2020-12-31', '2021-01-04', '2021-01-05', '2021-01-06',
#        '2021-01-07', '2021-01-08', '2021-01-11', '2021-01-12', '2021-01-13'],
#       dtype='object', name='Date', length=1258)

# %%
plt.plot(data.index,data.values)
