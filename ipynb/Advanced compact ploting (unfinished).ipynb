# %%
import pandas_datareader as pdr
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
sns.color_palette()
# Out:
# [(0.2980392156862745, 0.4470588235294118, 0.6901960784313725),
#  (0.8666666666666667, 0.5176470588235295, 0.3215686274509804),
#  (0.3333333333333333, 0.6588235294117647, 0.40784313725490196),
#  (0.7686274509803922, 0.3058823529411765, 0.3215686274509804),
#  (0.5058823529411764, 0.4470588235294118, 0.7019607843137254),
#  (0.5764705882352941, 0.47058823529411764, 0.3764705882352941),
#  (0.8549019607843137, 0.5450980392156862, 0.7647058823529411),
#  (0.5490196078431373, 0.5490196078431373, 0.5490196078431373),
#  (0.8, 0.7254901960784313, 0.4549019607843137),
#  (0.39215686274509803, 0.7098039215686275, 0.803921568627451)]

# %%
data = pdr.DataReader('AAPL', 'yahoo')

# %%
df = data[data.columns[-2:]]

# %%
df
# Out:
#                  Volume   Adj Close
# Date
# 2016-03-17  137682800.0   24.601379
# 2016-03-18  176820800.0   24.629284
# 2016-03-21  142010800.0   24.626959
# 2016-03-22  129777600.0   24.815302
# 2016-03-23  102814000.0   24.678110
# ...                 ...         ...
# 2021-03-10  111760400.0  119.980003
# 2021-03-11  102753600.0  121.959999
# 2021-03-12   87963400.0  121.029999
# 2021-03-15   92403800.0  123.989998
# 2021-03-16  114740000.0  125.570000
#
# [1258 rows x 2 columns]

# %%
fig = plt.figure(figsize=[9.6, 9.6])

# %%
ax0 = plt.subplot2grid((4,4), (0,0), rowspan=3, colspan=4, fig=fig)
ax1 = plt.subplot2grid((4,4), (3,0), rowspan=1, colspan=4, fig=fig, sharex=ax0)
ax1.set_facecolor('#fce4d6')
l0, = ax0.plot(df['Adj Close'])
plt.setp(ax0.get_xticklabels(), visible=False)
fig.subplots_adjust(hspace=0)
# or plt.subplots_adjust if fig declaration is in the same cell

ax1t = ax0.twinx()
ax1t.fill_between(df.index, df['Volume'], alpha=0.5)
ax1t.set_ylim(0, df['Volume'].max() * 3)
ax1t.set_yticks([df['Volume'].max()])
ax1t.grid(False)

# %%
ax1.set_facecolor('#fce4d6')
ax1.fill_between(df.index,0,df['Volume'], alpha=1) # alpha = tranparency
ax1.set_ylim(0)
ax1.set_yticks(ax1.get_yticks()[:-1])

# %%
fig

# %% [markdown]
# ### to be done

# %% [markdown]
# ax1 plot signal ignal data

# %%
# codes to deal with packed date ticks
# https://matplotlib.org/stable/gallery/ticks_and_spines/date_concise_formatter.html

import matplotlib.dates as mdates
import matplotlib.units as munits
munits.registry[np.datetime64] = mdates.ConciseDateConverter()

# %%
# codes to change tick labels to percentage

import matplotlib.ticker as mtick
ax1.yaxis.set_major_formatter(mtick.PercentFormatter())
