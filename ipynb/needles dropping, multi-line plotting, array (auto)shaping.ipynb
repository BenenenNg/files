# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Markdown
sns.set()

# %%
l = 0.3
n = 500

# %%
x = np.random.uniform(0, 5, n)
y = np.random.uniform(0, 5, n)
theta = np.random.uniform(0, np.pi, n)

x_offset = l / 2 * np.cos(theta)
y_offset = l / 2 * np.sin(theta)
x1 = x + x_offset
x2 = x - x_offset
y1 = y + y_offset
y2 = y - y_offset

needles = np.concatenate((x + [x_offset, -x_offset], y + [y_offset, -y_offset])).T.reshape(-1, 2)

# %%
m = ((x1 > np.array(range(6)).reshape(6,1)) != (x2 > np.array(range(6)).reshape(6,1))).sum()
m
# Out:
# 96

# %%
display(Markdown('### $\hat\pi=' + str(2 * n * l / d / m) + '$'))
# Out:
# ### $\hat\pi=3.125$

# %%
fig, ax = plt.subplots(figsize = [9.6, 9.6])
ax.vlines(range(6), 0, 5)
ax.plot(*needles, c='g');

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# # Void

# %%
cross = ((x1 > np.array(range(6)).reshape(6,1)) != (x2 > np.array(range(6)).reshape(6,1))).sum(axis=0)
cross = cross.astype('object')
cross[cross == 0] = 'g'
cross[cross == 1] = 'r'
cross = cross.reshape(1, -1)
